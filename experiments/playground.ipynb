# %%
import os
import sys
import subprocess

# Name your environment
venv_dir = "venv"

# Create venv
if not os.path.exists(venv_dir):
    print(f"Creating virtual environment in {venv_dir}...")
    subprocess.check_call([sys.executable, "-m", "venv", venv_dir])
else:
    print(f"Virtual environment {venv_dir} already exists.")

# Choose correct activation script based on OS
if os.name == "nt":  # Windows
    activate_script = os.path.join(venv_dir, "Scripts", "activate")
else:  # Unix/Linux/Mac
    activate_script = os.path.join(venv_dir, "bin", "activate")

print(f"✅ Venv setup done. Activate manually if needed: {activate_script}")
# Out:
# Virtual environment venv already exists.
# ✅ Venv setup done. Activate manually if needed: venv\Scripts\activate

# %%
import subprocess

# Define your requirements file
requirements_file = "requirements.txt"

# Check if requirements.txt exists
if not os.path.isfile(requirements_file):
    print(f"❌ {requirements_file} not found. Create it first.")
else:
    print(f"Installing from {requirements_file}...")
    
    # Find pip inside the venv
    pip_path = os.path.join(venv_dir, "bin", "pip") if os.name != "nt" else os.path.join(venv_dir, "Scripts", "pip.exe")
    
    # Use subprocess.run instead of check_call
    result = subprocess.run(
        [pip_path, "install", "-r", requirements_file],
        capture_output=True,
        text=True
    )

    # Always print the output
    print("--- stdout ---")
    print(result.stdout)
    print("--- stderr ---")
    print(result.stderr)

    # Check if pip succeeded
    if result.returncode != 0:
        raise Exception(f"❌ pip install failed with exit code {result.returncode}")
    else:
        print(f"✅ Installed requirements from {requirements_file}.")
# Out:
# Installing from requirements.txt...
# --- stdout ---
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# Requirement already satisfied: opencv-python in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from -r requirements.txt (line 1)) (4.11.0.86)
# Requirement already satisfied: pytesseract in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from -r requirements.txt (line 2)) (0.3.13)
# Requirement already satisfied: matplotlib in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from -r requirements.txt (line 3)) (3.10.1)
# Collecting easyocr
#   Using cached easyocr-1.7.2-py3-none-any.whl (2.9 MB)
# Requirement already satisfied: torch==2.2.1+cu118 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from -r requirements.txt (line 5)) (2.2.1+cu118)
# Requirement already satisfied: torchvision==0.17.1+cu118 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from -r requirements.txt (line 6)) (0.17.1+cu118)
# Requirement already satisfied: torchaudio==2.2.1+cu118 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from -r requirements.txt (line 7)) (2.2.1+cu118)
# Requirement already satisfied: filelock in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from torch==2.2.1+cu118->-r requirements.txt (line 5)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from torch==2.2.1+cu118->-r requirements.txt (line 5)) (4.13.2)
# Requirement already satisfied: sympy in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from torch==2.2.1+cu118->-r requirements.txt (line 5)) (1.13.3)
# Requirement already satisfied: networkx in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from torch==2.2.1+cu118->-r requirements.txt (line 5)) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from torch==2.2.1+cu118->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from torch==2.2.1+cu118->-r requirements.txt (line 5)) (2025.3.2)
# Requirement already satisfied: numpy in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from torchvision==0.17.1+cu118->-r requirements.txt (line 6)) (2.2.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from torchvision==0.17.1+cu118->-r requirements.txt (line 6)) (11.2.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from pytesseract->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (2.9.0.post0)
# Collecting opencv-python-headless
#   Using cached opencv_python_headless-4.11.0.86-cp37-abi3-win_amd64.whl (39.4 MB)
# Requirement already satisfied: scipy in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from easyocr->-r requirements.txt (line 4)) (1.15.2)
# Collecting scikit-image
#   Using cached scikit_image-0.25.2-cp311-cp311-win_amd64.whl (12.8 MB)
# Requirement already satisfied: python-bidi in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from easyocr->-r requirements.txt (line 4)) (0.6.6)
# Requirement already satisfied: PyYAML in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from easyocr->-r requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: Shapely in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from easyocr->-r requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: pyclipper in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from easyocr->-r requirements.txt (line 4)) (1.3.0.post6)
# Collecting ninja
#   Using cached ninja-1.11.1.4-py3-none-win_amd64.whl (296 kB)
# Requirement already satisfied: six>=1.5 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from jinja2->torch==2.2.1+cu118->-r requirements.txt (line 5)) (3.0.2)
# Collecting imageio!=2.35.0,>=2.33
#   Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from scikit-image->easyocr->-r requirements.txt (line 4)) (2025.3.30)
# Collecting lazy-loader>=0.4
#   Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rohan\downloads\cs224r-proj\venv\lib\site-packages (from sympy->torch==2.2.1+cu118->-r requirements.txt (line 5)) (1.3.0)
# Installing collected packages: opencv-python-headless, ninja, lazy-loader, imageio, scikit-image, easyocr
#
# --- stderr ---
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\rohan\\Downloads\\CS224R-proj\\venv\\Lib\\site-packages\\cv2\\cv2.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip available: 22.3 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[21], line 30
#      28 # Check if pip succeeded
#      29 if result.returncode != 0:
# ---> 30     raise Exception(f"❌ pip install failed with exit code {result.returncode}")
#      31 else:
#      32     print(f"✅ Installed requirements from {requirements_file}.")
#
# Exception: ❌ pip install failed with exit code 1

# %%
import cv2, pytesseract, numpy as np, re, matplotlib.pyplot as plt
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

ROI     = slice(-227, -211), slice(78, 175)
SCALE   = 100
CFG     = "--oem 3 --psm 7 -c tessedit_char_whitelist=0123456789/"
PAT     = re.compile(r"\d+/\d+")

def ocr_bar(bar_bgr, debug=False):
    big   = cv2.resize(bar_bgr, None, fx=SCALE, fy=SCALE, interpolation=cv2.INTER_CUBIC)
    blur  = cv2.GaussianBlur(big, (0, 0), 1.2)
    sharp = cv2.addWeighted(big, 1.5, blur, -0.5, 0)

    hsv   = cv2.cvtColor(sharp, cv2.COLOR_BGR2HSV)
    s, v  = hsv[:, :, 1], hsv[:, :, 2]
    mask  = ((s < 140) & (v > 120)).astype(np.uint8) * 255

    k     = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    mask  = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, k, 1)
    mask  = cv2.dilate(mask, k, 1)

    inv   = cv2.bitwise_not(mask)
    txt   = pytesseract.image_to_string(inv, config=CFG).strip()
    txt   = txt if PAT.fullmatch(txt) else ""
    return (txt, inv) if debug else txt

# --------------------------------------------------------------
cap = cv2.VideoCapture("replays/sample.mp4")

for fn in range(1, 10_001, 1_000):
    cap.set(cv2.CAP_PROP_POS_FRAMES, fn)
    ret, frame = cap.read();  assert ret

    bar = frame[ROI]
    text, dbg = ocr_bar(bar, debug=True)

    # --- NEW: print to console -----------------------------------
    print(f"frame {fn:5}: {text!r}")

    # --- visual debug (optional) ---------------------------------
    fig, ax = plt.subplots(1, 2, figsize=(7, 3))
    ax[0].imshow(cv2.cvtColor(bar, cv2.COLOR_BGR2RGB)); ax[0].set_title(f"frame {fn}")
    ax[0].axis("off")
    ax[1].imshow(dbg, cmap="gray");                    ax[1].set_title(f"OCR → {text or '…'}")
    ax[1].axis("off")
    plt.tight_layout(); plt.show()

cap.release()
# Out:
# frame     1: '800/800'
# frame  1001: '800/800'
# frame  2001: '174/881'
# frame  3001: '435/881'
# frame  4001: '42/884'
# frame  5001: '211/968'
# frame  6001: '835/971'
# frame  7001: ''
# frame  8001: '941/91'
# frame  9001: '10611/7001'

# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt
import numpy as np

# Update the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Load the video
video_path = 'replays/sample.mp4'
video_capture = cv2.VideoCapture(video_path)

# Specify the frame number you want to extract
frame_number = 17000
#16000
# Set the video capture to the specific frame
video_capture.set(cv2.CAP_PROP_POS_FRAMES, frame_number)

# Read the frame
success, frame = video_capture.read()

frame = frame[-228:-210,75:175]
hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
plt.imshow(hsv[:,:,0])
plt.show()
plt.imshow(hsv[:,:,1])
plt.show()
plt.imshow(hsv[:,:,2])
plt.show()
#CODE HERE
frame = hsv[:,:,1]
# Use Tesseract to extract text
text = pytesseract.image_to_string(frame, lang='eng',config='--oem 3 --psm 6')


print(text)

# Release the video capture object
video_capture.release()

plt.imshow(frame, cmap='gray')
plt.show()
# Out:
# ee

# %%
import cv2
import easyocr
import matplotlib.pyplot as plt

# Load the video
video_path = 'replays/sample.mp4'
video_capture = cv2.VideoCapture(video_path)

# Specify the frame number you want to extract
frame_number = 2000

# Set the video capture to the specific frame
video_capture.set(cv2.CAP_PROP_POS_FRAMES, frame_number)

# Read the frame
success, frame = video_capture.read()
frame = frame[-152:-141,50:118,]
# Convert the image to grayscale
gray_image = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

# Apply thresholding to binarize the image
_, binary_image = cv2.threshold(gray_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Initialize EasyOCR reader
reader = easyocr.Reader(['en'])

# Perform OCR on the image
result = reader.readtext(binary_image, detail=0)

# Print the recognized text
print("Recognized text:", result)

# Display the processed image
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Binary Image for OCR')
plt.imshow(binary_image, cmap='gray')
plt.axis('off')

plt.show()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.5 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py", line 604, in run_forever
#     self._run_once()
#   File "c:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "c:\Users\rohan\AppData\Local\Programs\Python\Python311\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\rohan\AppData\Local\Temp\ipykernel_61040\979737855.py", line 2, in <module>
#     import easyocr
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\easyocr\__init__.py", line 1, in <module>
#     from .easyocr import Reader
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\easyocr\easyocr.py", line 3, in <module>
#     from .recognition import get_recognizer, get_text
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\easyocr\recognition.py", line 2, in <module>
#     import torch
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\torch\__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\torch\functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\torch\nn\__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\torch\nn\modules\__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\torch\nn\modules\transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\torch\nn\modules\transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ..\torch\csrc\utils\tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 28
#      25 reader = easyocr.Reader(['en'])
#      27 # Perform OCR on the image
# ---> 28 result = reader.readtext(binary_image, detail=0)
#      30 # Print the recognized text
#      31 print("Recognized text:", result)
#
# File c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\easyocr\easyocr.py:456, in Reader.readtext(self, image, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, min_size, contrast_ths, adjust_contrast, filter_ths, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, y_ths, x_ths, add_margin, threshold, bbox_min_score, bbox_min_size, max_candidates, output_format)
#     450 '''
#     451 Parameters:
#     452 image: file path or numpy-array or a byte stream object
#     453 '''
#     454 img, img_cv_grey = reformat_input(image)
# --> 456 horizontal_list, free_list = self.detect(img,
#     457                                          min_size = min_size, text_threshold = text_threshold,\
#     458                                          low_text = low_text, link_threshold = link_threshold,\
#     459                                          canvas_size = canvas_size, mag_ratio = mag_ratio,\
#     460                                          slope_ths = slope_ths, ycenter_ths = ycenter_ths,\
#     461                                          height_ths = height_ths, width_ths= width_ths,\
#     462                                          add_margin = add_margin, reformat = False,\
#     463                                          threshold = threshold, bbox_min_score = bbox_min_score,\
#     464                                          bbox_min_size = bbox_min_size, max_candidates = max_candidates
#     465                                          )
#     466 # get the 1st result from hor & free list as self.detect returns a list of depth 3
#     467 horizontal_list, free_list = horizontal_list[0], free_list[0]
#
# File c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\easyocr\easyocr.py:321, in Reader.detect(self, img, min_size, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, add_margin, reformat, optimal_num_chars, threshold, bbox_min_score, bbox_min_size, max_candidates)
#     318 if reformat:
#     319     img, img_cv_grey = reformat_input(img)
# --> 321 text_box_list = self.get_textbox(self.detector,
#     322                             img,
#     323                             canvas_size = canvas_size,
#     324                             mag_ratio = mag_ratio,
#     325                             text_threshold = text_threshold,
#     326                             link_threshold = link_threshold,
#     327                             low_text = low_text,
#     328                             poly = False,
#     329                             device = self.device,
#     330                             optimal_num_chars = optimal_num_chars,
#     331                             threshold = threshold,
#     332                             bbox_min_score = bbox_min_score,
#     333                             bbox_min_size = bbox_min_size,
#     334                             max_candidates = max_candidates,
#     335                             )
#     337 horizontal_list_agg, free_list_agg = [], []
#     338 for text_box in text_box_list:
#
# File c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\easyocr\detection.py:95, in get_textbox(detector, image, canvas_size, mag_ratio, text_threshold, link_threshold, low_text, poly, device, optimal_num_chars, **kwargs)
#      93 result = []
#      94 estimate_num_chars = optimal_num_chars is not None
# ---> 95 bboxes_list, polys_list = test_net(canvas_size, mag_ratio, detector,
#      96                                    image, text_threshold,
#      97                                    link_threshold, low_text, poly,
#      98                                    device, estimate_num_chars)
#      99 if estimate_num_chars:
#     100     polys_list = [[p for p, _ in sorted(polys, key=lambda x: abs(optimal_num_chars - x[1]))]
#     101                   for polys in polys_list]
#
# File c:\Users\rohan\Downloads\CS224R-proj\venv\Lib\site-packages\easyocr\detection.py:41, in test_net(canvas_size, mag_ratio, net, image, text_threshold, link_threshold, low_text, poly, device, estimate_num_chars)
#      38 # preprocessing
#      39 x = [np.transpose(normalizeMeanVariance(n_img), (2, 0, 1))
#      40      for n_img in img_resized_list]
# ---> 41 x = torch.from_numpy(np.array(x))
#      42 x = x.to(device)
#      44 # forward pass
#
# RuntimeError: Numpy is not available

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

video_path = 'replays/sample.mp4'
video_capture = cv2.VideoCapture(video_path)

# Specify the frame numbers you want to extract
for i in range(1, 50000, 1000):
    frame_number = i
    # Set the video capture to the specific frame
    video_capture.set(cv2.CAP_PROP_POS_FRAMES, frame_number)

    # Read the frame
    success, og_frame = video_capture.read()
    if not success:
        break
    og_frame = og_frame[-228:-210, 75:175]

    # Convert frame to HSV color space
    hsv_frame = cv2.cvtColor(og_frame, cv2.COLOR_BGR2HSV)

    # Define the green color range in HSV
    lower_green = np.array([40, 40, 40])
    upper_green = np.array([80, 255, 255])

    # Create a mask for the green background
    green_mask = cv2.inRange(hsv_frame, lower_green, upper_green)

    # Invert the mask to get the text
    text_mask = cv2.bitwise_not(green_mask)

    # Find contours of the text
    contours, _ = cv2.findContours(text_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    plt.imshow(contours)
    plt.show()

    # Initialize bounding box variables
    x, y, w, h = 0, 0, og_frame.shape[1], og_frame.shape[0]

    if contours:
        # Get the bounding box of the largest contour
        x, y, w, h = cv2.boundingRect(contours[0])
        for contour in contours[1:]:
            new_x, new_y, new_w, new_h = cv2.boundingRect(contour)
            x = min(x, new_x)
            y = min(y, new_y)
            w = max(w, new_w)
            h = max(h, new_h)

    # Crop the frame to the bounding box
    cropped_frame = og_frame[y:y+h, x:x+w]

    # Display the cropped frame
    plt.imshow(cv2.cvtColor(cropped_frame, cv2.COLOR_BGR2RGB))
    plt.title(f'Frame {frame_number}')
    plt.show()

# Release the video capture object
video_capture.release()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <module>
#      33 # Find contours of the text
#      34 contours, _ = cv2.findContours(text_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# ---> 36 plt.imshow(contours)
#      37 plt.show()
#      39 # Initialize bounding box variables
#
# File c:\Users\rohan\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
#    2691         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2692         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
#    2696         X, cmap=cmap, norm=norm, aspect=aspect,
#    2697         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2698         vmax=vmax, origin=origin, extent=extent,
#    2699         interpolation_stage=interpolation_stage,
#    2700         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2701         url=url, **({"data": data} if data is not None else {}),
#    2702         **kwargs)
#    2703     sci(__ret)
#    2704     return __ret
#
# File c:\Users\rohan\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py:1461, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1458 @functools.wraps(func)
#    1459 def inner(ax, *args, data=None, **kwargs):
#    1460     if data is None:
# -> 1461         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1463     bound = new_sig.bind(ax, *args, **kwargs)
#    1464     auto_label = (bound.arguments.get(label_namer)
#    1465                   or bound.kwargs.get(label_namer))
#
# File c:\Users\rohan\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:5663, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5655 self.set_aspect(aspect)
#    5656 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5657                       interpolation=interpolation, origin=origin,
#    5658                       extent=extent, filternorm=filternorm,
#    5659                       filterrad=filterrad, resample=resample,
#    5660                       interpolation_stage=interpolation_stage,
#    5661                       **kwargs)
# -> 5663 im.set_data(X)
#    5664 im.set_alpha(alpha)
#    5665 if im.get_clip_path() is None:
#    5666     # image does not already have clipping set, clip to axes patch
#
# File c:\Users\rohan\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\image.py:697, in _ImageBase.set_data(self, A)
#     695 if isinstance(A, PIL.Image.Image):
#     696     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 697 self._A = cbook.safe_masked_invalid(A, copy=True)
#     699 if (self._A.dtype != np.uint8 and
#     700         not np.can_cast(self._A.dtype, float, "same_kind")):
#     701     raise TypeError("Image data of dtype {} cannot be converted to "
#     702                     "float".format(self._A.dtype))
#
# File c:\Users\rohan\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\cbook\__init__.py:714, in safe_masked_invalid(x, copy)
#     713 def safe_masked_invalid(x, copy=False):
# --> 714     x = np.array(x, subok=True, copy=copy)
#     715     if not x.dtype.isnative:
#     716         # If we have already made a copy, do the byteswap in place, else make a
#     717         # copy with the byte order swapped.
#     718         x = x.byteswap(inplace=copy).newbyteorder('N')  # Swap to native order.
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (12,) + inhomogeneous part.
